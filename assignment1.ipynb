# %%
print("hello world")
# Out:
# hello world

# %%
my_list=[3,0,2,1]
my_list.insert(2,3)
my_list.reverse()
print(my_list)
# Out:
# [1, 2, 3, 0, 3]

# %%
tuple=(0,1,1,2,4,5)
print(tuple[1:])
print(tuple[1:4])
# Out:
# (1, 1, 2, 4, 5)
# (1, 1, 2)

# %%
s="1024170404"
list=[]
j=0
for i in s:
    k=int(i)
    k=k*10
    list.insert(j,k)
    j=j+1
print(list)
list.append(2)#2 inserted at eo list
list.insert(5,2)#2 inserted at index 5
list.remove(10)
print(list)
print(list.pop(3))
list.sort()
list.sort(reverse="True")
print(list)
print(list[0:3])
print(list[7:])
# Out:
# [10, 0, 20, 40, 10, 70, 0, 40, 0, 40]
# [0, 20, 40, 10, 2, 70, 0, 40, 0, 40, 2]
# 10
# [70, 40, 40, 40, 20, 2, 2, 0, 0, 0]
# [70, 40, 40]
# [0, 0, 0]

# %%
tuple=(24,35,45,21,76,87,35,97)
print(max(tuple))
print(tuple.index(max(tuple)))
list=[]
j=0
for i in tuple:
    list.insert(j,i)
    j=j+1
    list.reverse()
print(list)
# Out:
# 97
# 7
# [97, 87, 21, 35, 24, 45, 76, 35]

# %%
my_dict = { "name": "maitreya", "roll_no": "1024170404", "branch": "compsci", "age": 19, "city": "gurgaon" }
